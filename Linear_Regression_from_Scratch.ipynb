# %% [markdown]
# <a href="https://colab.research.google.com/github/Saicharan-007/Linear-Regression-Assumptions/blob/main/Linear_Regression_from_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("50_Startups.csv")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[3])],remainder='passthrough')
x=np.array(ct.fit_transform(x))

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-7.17740563e-01, -6.85994341e-01,  1.39326109e+00,
#          2.01641149e+00,  5.60752915e-01,  2.15394309e+00],
#        [ 1.39326109e+00, -6.85994341e-01, -7.17740563e-01,
#          1.95586034e+00,  1.08280658e+00,  1.92360040e+00],
#        [-7.17740563e-01,  1.45773797e+00, -7.17740563e-01,
#          1.75436374e+00, -7.28257028e-01,  1.62652767e+00],
#        [-7.17740563e-01, -6.85994341e-01,  1.39326109e+00,
#          1.55478369e+00, -9.63646307e-02,  1.42221024e+00],
#        [-7.17740563e-01,  1.45773797e+00, -7.17740563e-01,
#          1.50493720e+00, -1.07991935e+00,  1.28152771e+00],
#        [-7.17740563e-01, -6.85994341e-01,  1.39326109e+00,
#          1.27980001e+00, -7.76239071e-01,  1.25421046e+00],
#        [ 1.39326109e+00, -6.85994341e-01, -7.17740563e-01,
#          1.34006641e+00,  9.32147208e-01, -6.88149930e-01],
#        [-7.17740563e-01,  1.45773797e+00, -7.17740563e-01,
#          1.24505666e+00,  8.71980011e-01,  9.32185978e-01],
# ...

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# Creating the Cost and gradient function

# %%
def CostFunction(x,y,w,b):
  cost=np.sum((((x.dot(w)+b)-y)**2)/(2*len(y)))
  return cost
def GradientDescent(x,y,w,b,learning_rate,epochs):
  cost_list=[0]*epochs
  for epoch in range(epochs):
    z=x.dot(w)+b
    loss=z-y
    weight_gradient=x.T.dot(loss)/len(y)
    bias_gradient=np.sum(loss)/len(y)
    w=w-learning_rate*weight_gradient
    b=b-learning_rate*bias_gradient
    cost=CostFunction(x,y,w,b)
    cost_list[epoch]=cost
    if(epoch%(epochs/10)==0):
      print("cost is:",cost)
  return w,b,cost_list

# %% [markdown]
# Calculating weights and bias

# %%
w,b,c=GradientDescent(Xtrain,Ytrain,np.zeros(Xtrain.shape[1]),0,0.002,epochs=15000)
# Out:
# cost is: 6989316078.6237135
# cost is: 93910079.250253
# cost is: 52213406.460179575
# cost is: 44053387.931024216
# cost is: 41718884.29335991
# cost is: 41048136.3698332
# cost is: 40855409.298071906
# cost is: 40800032.694304764
# cost is: 40784121.23860737
# cost is: 40779549.37241818

# %% [markdown]
# Plotting the cost

# %%
plt.plot(c)

# %% [markdown]
# Predicting lables with the calculated weights and biases

# %%
def predict(X,w,b):
  return X.dot(w)+b
y_pred=predict(Xtest,w,b)
y_pred
# Out:
# array([126193.33929409,  85778.28789187,  99712.26881752,  45687.011148  ,
#        127083.38196704,  51822.14308521, 109074.5511469 , 100588.06634294,
#         97896.91148469, 111646.96672642, 128797.16331577, 174150.50690473,
#         93707.59244805, 148391.46889529, 172310.08314671])

# %% [markdown]
# Calculating the R2 Score

# %%
def r2score(y_pred,y):
  rss=np.sum((y_pred-y)**2)
  tss=np.sum((y-y.mean())**2)
  r2=1-(rss/tss)
  return r2
r2score(y_pred,Ytest)
# Out:
# 0.9397254670323116
